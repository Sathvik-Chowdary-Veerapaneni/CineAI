# %%
#Importing libraries

import pandas as pd
import json
import os

# %%
# !pip install pandas

# %%
# Loading the json data 
root_data_dir='/Users/HVMS/Desktop/GitHub/CineAI/data'

# %%
for sub_dir in sorted(os.listdir(root_data_dir)):
    print(sub_dir)  # Print each subdirectory in order
# Out:
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023

# %%
for sub_dir in sorted(os.listdir(root_data_dir+ '/2000/')):
    print(sub_dir)
# Out:
# batch_001.json
# batch_002.json
# batch_003.json
# batch_004.json
# batch_005.json
# batch_006.json
# batch_007.json
# batch_008.json

# %%
test_batch_1_2000 = root_data_dir+ '/2000/batch_001.json'
with open(test_batch_1_2000, 'r') as file_1:
    data_1 = json.load(file_1)

# %%
len(data_1)
# Out:
# 1000

# %%
#To get movie ID
for movie_id in data_1:
    for keys,values in movie_id.items():
        print(keys)
# Out:
# 98
# 8871
# 7443
# 9532
# 77
# 8358
# 22705
# 10867
# 4247
# 11688
# 10567
# 2123
# 2024
# 1359
# 1443
# 4234
# 3134
# 8843
# 5833
# 10501
# 1443
# 8358
# 10637
# 1900
# 10577
# 1636
# 9741
# 16366
# 107
# 2085
# 5994
# 5833
# 9600
# 2069
# 9679
# 11978
# 843
# 3536
# 20677
# 9383
# 9679
# 11978
# 9383
# 8584
# 1907
# 146
# 10559
# 10393
# 12107
# 3176
# 2085
# 1636
# 1493
# 10647
# 2655
# 59709
# 11518
# 10035
# 15999
# 19576
# 20677
# 10577
# 3536
# 16234
# 243
# 10481
# 10876
# 19457
# 71
# 10991
# 2155
# 9600
# 10783
# 36968
# 5551
# 2440
# 15653
# 49948
# 8452
# 641
# 2069
# 2067
# 5491
# 16
# 11075
# 9456
# 1597
# 134
# 889
# 4244
# 10571
# 55892
# 20770
# 8859
# 10461
# 12609
# 2332
# 10687
# 11973
# 21614
# 10571
# 5551
# 889
# 479
# 7290
# 20455
# 18079
# 8653
# 18041
# 14626
# 8452
# 49948
# 19419
# 1588
# 10641
# 105904
# 10471
# 24102
# 10873
# 193457
# 1588
# 30628
# 4958
# 101514
# 2787
# 31347
# 41245
# 447399
# 62182
# 392
# 10569
# 11366
# 12211
# 9871
# 105904
# 711
# 327
# 18011
# 10473
# 10862
# 8653
# 193457
# 16340
# 16187
# 117087
# 10385
# 8870
# 12480
# 10560
# 10597
# 18041
# 10429
# 11983
# 14805
# 10472
# 48246
# 13785
# 37588
# 60670
# 55888
# 10873
# 24102
# 1163
# 14181
# 919
# 10642
# 44321
# 44853
# 28031
# 11599
# 10562
# 21355
# 24100
# 41275
# 12650
# 24664
# 24476
# 10180
# 10480
# 30970
# 18079
# 19348
# 4226
# 6521
# 318
# 40466
# 27092
# 14736
# 10763
# 1837
# 9674
# 5001
# 2621
# 39468
# 20455
# 37302
# 2360
# 49979
# 29458
# 16225
# 31352
# 17908
# 18074
# 11119
# 112
# 258919
# 10688
# 30944
# 21531
# 16888
# 159666
# 11477
# 10383
# 11478
# 29572
# 1619
# 27181
# 29512
# 29015
# 12597
# 7290
# 19419
# 12619
# 27027
# 15489
# 40096
# 10416
# 9011
# 1242945
# 15319
# 14295
# 16990
# 742
# 37691
# 1698
# 336970
# 36301
# 17711
# 9791
# 4967
# 32834
# 1831
# 22597
# 16110
# 38047
# 75571
# 13930
# 10394
# 44203
# 92208
# 20993
# 13966
# 3178
# 89473
# 200995
# 19150
# 87867
# 9519
# 35650
# 10697
# 10394
# 258919
# 11119
# 12480
# 15489
# 52684
# 10391
# 30940
# 1609
# 18168
# 39468
# 8870
# 190794
# 18074
# 51333
# 21991
# 34729
# 65592
# 37722
# 2805
# 18168
# 51333
# 18292
# 196737
# 20637
# 22617
# 193932
# 244839
# 55101
# 131940
# 5257
# 34729
# 20697
# 98299
# 52654
# 197725
# 12509
# 26245
# 32250
# 36234
# 37722
# 39242
# 4973
# 50008
# 27711
# 27099
# 204839
# 44412
# 49291
# 48944
# 52684
# 50531
# 3716
# 7093
# 190794
# 44388
# 29270
# 14195
# 44379
# 23990
# 2805
# 32536
# 27320
# 14629
# 42332
# 60703
# 28346
# 43586
# 576359
# 87107
# 43555
# 10391
# 20067
# 64269
# 53105
# 415488
# 46462
# 19214
# 33347
# 25128
# 71887
# 36380
# 49135
# 27745
# 34899
# 27444
# 10305
# 12806
# 60587
# 21056
# 299024
# 65592
# 248058
# 92620
# 25014
# 23618
# 44490
# 71235
# 26450
# 45438
# 25014
# 23618
# 89473
# 248058
# 45438
# 26450
# 44490
# 348864
# 51531
# 61064
# 87867
# 60703
# 71235
# 207693
# 41656
# 31774
# 5247
# 44933
# 288116
# 2707
# 51107
# 32309
# 89297
# 207937
# 10205
# 19349
# 72753
# 41282
# 12724
# 21370
# 30940
# 106230
# 45418
# 44488
# 62127
# 350893
# 48328
# 41165
# 10499
# 157800
# 77519
# 45488
# 34027
# 261111
# 72356
# 31875
# 16275
# 45602
# 42877
# 9375
# 45511
# 85411
# 47595
# 166813
# 685908
# 46958
# 44756
# 21174
# 36047
# 444008
# 22426
# 35066
# 45861
# 51767
# 31053
# 33504
# 49514
# 47943
# 28745
# 25636
# 61064
# 291334
# 77921
# 45573
# 55296
# 221506
# 2089
# 110977
# 50380
# 15940
# 81277
# 125173
# 118727
# 29866
# 35064
# 77434
# 100607
# 6147
# 40249
# 26665
# 32567
# 81207
# 31443
# 267409
# 32067
# 44947
# 60074
# 23531
# 37998
# 322686
# 38132
# 3173
# 193526
# 39927
# 13898
# 43079
# 214680
# 47244
# 39056
# 174412
# 12255
# 18394
# 46406
# 10613
# 13899
# 9883
# 10558
# 60579
# 36273
# 10989
# 291312
# 39907
# 34856
# 196280
# 88494
# 120128
# 389437
# 49709
# 20152
# 19505
# 36246
# 195791
# 45043
# 17208
# 39880
# 50477
# 230562
# 27859
# 30440
# 38274
# 31610
# 348862
# 24470
# 187107
# 111244
# 25212
# 25520
# 62004
# 14273
# 34037
# 31776
# 55551
# 47191
# 9301
# 45389
# 51179
# 106813
# 218188
# 16404
# 72392
# 610133
# 45463
# 188032
# 407312
# 37047
# 45124
# 56666
# 48217
# 36753
# 15869
# 604999
# 54380
# 29937
# 75531
# 264117
# 9565
# 11925
# 54690
# 218183
# 52409
# 34704
# 19600
# 186315
# 57450
# 20883
# 33994
# 114162
# 64526
# 10469
# 17806
# 291726
# 203071
# 43592
# 36923
# 60119
# 25293
# 45548
# 77787
# 49453
# 195655
# 329269
# 27734
# 127849
# 1051942
# 75049
# 344225
# 61578
# 58195
# 21117
# 45490
# 38294
# 85214
# 108811
# 107277
# 52622
# 61849
# 28943
# 55921
# 428006
# 21842
# 291721
# 26436
# 153913
# 76177
# 51422
# 34299
# 75697
# 77576
# 167880
# 20438
# 106199
# 95136
# 276846
# 52790
# 90881
# 431229
# 213914
# 38135
# 166231
# 72261
# 51531
# 348864
# 36817
# 64266
# 61641
# 109051
# 52051
# 22470
# 30148
# 78452
# 52852
# 20276
# 45952
# 47724
# 77332
# 154299
# 496537
# 36044
# 103152
# 47302
# 207693
# 27540
# 72998
# 71115
# 15090
# 18778
# 89345
# 44387
# 302466
# 38503
# 211277
# 44047
# 25651
# 200419
# 433111
# 887789
# 40562
# 29136
# 69426
# 27742
# 58976
# 45905
# 5643
# 9892
# 271917
# 3218
# 43674
# 68572
# 28349
# 354674
# 122163
# 51861
# 68820
# 60452
# 171120
# 64357
# 874667
# 446774
# 62333
# 81760
# 89068
# 54986
# 124134
# 326924
# 273106
# 9995
# 49035
# 46119
# 37716
# 45055
# 41571
# 30809
# 74578
# 28988
# 637105
# 117262
# 44131
# 23751
# 273510
# 48123
# 29946
# 45123
# 186047
# 206163
# 5245
# 39498
# 206053
# 86008
# 10415
# 214246
# 72270
# 612521
# 201447
# 41425
# 71618
# 434965
# 76265
# 106234
# 75217
# 31920
# 66796
# 49785
# 31001
# 116790
# 416715
# 443716
# 205608
# 86781
# 217428
# 256104
# 115717
# 78962
# 113213
# 3152
# 140511
# 330698
# 126733
# 209084
# 100801
# 56419
# 203831
# 52833
# 66464
# 24104
# 24955
# 55026
# 49511
# 41644
# 357682
# 58062
# 289673
# 80959
# 281014
# 85265
# 265760
# 351196
# 450187
# 452440
# 15993
# 287807
# 175240
# 27736
# 395337
# 20445
# 41381
# 88660
# 99754
# 28127
# 62729
# 447511
# 60065
# 76819
# 188154
# 248904
# 44574
# 200919
# 256050
# 70773
# 30947
# 385502
# 50477
# 38274
# 51824
# 164123
# 191378
# 267569
# 281308
# 2394
# 115469
# 41738
# 62004
# 31610
# 477164
# 33901
# 49453
# 106813
# 25212
# 37047
# 352815
# 45389
# 348762
# 254981
# 447719
# 171106
# 72087
# 16874
# 276456
# 27336
# 64114
# 107975
# 99011
# 155666
# 110999
# 181056
# 128862
# 11303
# 178582
# 21620
# 598278
# 384093
# 31006
# 277073
# 34794
# 158431
# 55143
# 20585
# 71884
# 167087
# 71550
# 116011
# 343321
# 30780
# 408129
# 414353
# 21488
# 290537
# 32249
# 118170
# 423976
# 880144
# 254981
# 201447
# 11925
# 56419
# 302466
# 330443
# 302508
# 390948
# 259730
# 16673
# 218183
# 67252
# 160832
# 41644
# 264806
# 356083
# 252615
# 245934
# 48868
# 73455
# 67252
# 376730
# 922327
# 165573
# 37730
# 364475
# 235423
# 88007
# 15496
# 23655
# 73642
# 29941
# 96716
# 33901
# 453230
# 31321
# 321023
# 1021910
# 351208
# 156682
# 107312
# 55302
# 63607
# 107942
# 286922
# 693072
# 79704
# 45203
# 49947
# 81219
# 69659
# 123187
# 82348
# 40930
# 1024825
# 213867
# 74824
# 271667
# 23430
# 44845
# 267569
# 103688
# 261459
# 340017
# 284183
# 844452
# 641425
# 45302
# 72244
# 10492
# 166283
# 75953
# 60585
# 62124
# 155588
# 75864
# 109926
# 75778
# 279700
# 364264
# 191378
# 41738
# 1185915
# 160832
# 88910
# 221501
# 1184877
# 57704
# 51864
# 169801
# 82103
# 102242
# 42195
# 24908
# 390959
# 252356
# 701212
# 38390
# 38987
# 18153
# 477164
# 318602
# 360411
# 31778
# 203820
# 45474
# 194529
# 77620
# 83581
# 434134
# 345864
# 48868
# 366978
# 66159
# 214014
# 261561
# 64310
# 34056
# 315978
# 116688
# 201724
# 1107965
# 166899
# 112977
# 77908
# 73838
# 448324
# 39793
# 199747
# 83870
# 40010
# 1009586
# 104613
# 217175
# 182511
# 221841
# 229428
# 88634
# 265307
# 106490
# 77332
# 47724
# 25651
# 66796
# 45952
# 45302
# 78620
# 132393
# 208910
# 10561
# 31920
# 89345
# 152163
# 267512
# 44387
# 15090
# 426506
# 40390
# 2090
# 471732
# 352815
# 79080
# 196139
# 30717
# 114620
# 273410
# 427108
# 239547
# 209133
# 231193
# 89823
# 339308
# 103635
# 1067248
# 436039
# 49773
# 23537
# 27775
# 31140
# 161219

# %%
# To get movie individual keys columns such as(endpoints) - expecting 15 endpoints

first_movie = data_1[0]
movie_id = list(first_movie.keys())[0]
endpoints = first_movie[movie_id].keys()

print(f"Endpoints for movie ID {movie_id}:")
for endpoint in endpoints:
    print(f"- {endpoint}")
# Out:
# Endpoints for movie ID 98:
# - details
# - credits
# - recommendations
# - watch_providers

# %%
# Getting keys from 'details' endpoint for first movie
first_movie = data_1[0]  # Get first movie
movie_id = list(first_movie.keys())[0]  # Get movie ID


details_keys = first_movie[movie_id]['details'].keys()

print(f"\nKeys in 'details' for movie {movie_id}:")
for key in sorted(details_keys):
    print(f"- {key}")
# Out:
# Keys in 'details' for movie 98:
# - genres
# - id
# - original_language
# - overview
# - popularity
# - release_date
# - runtime
# - title

# %%
# Getting the first movie and its ID
movie = data_1[0]
movie_id = list(movie.keys())[0]
movie_data = movie[movie_id]

# Print all endpoint keys
print(f"\nAll endpoint keys for movie ID {movie_id}:")
for endpoint in sorted(movie_data.keys()):
    print(f"\n{endpoint.upper()} keys:")
    try:
        keys = movie_data[endpoint].keys()
        for key in sorted(keys):
            print(f"- {key}")
    except AttributeError:
        print("(No nested keys)")
# Out:
# All endpoint keys for movie ID 98:
#
# CREDITS keys:
# - cast
# - crew
#
# DETAILS keys:
# - genres
# - id
# - original_language
# - overview
# - popularity
# - release_date
# - runtime
# - title
#
# RECOMMENDATIONS keys:
# - results
#
# WATCH_PROVIDERS keys:
# - results

# %%
movie = data_1[0]
movie_id = list(movie.keys())[0]
movie_data = movie[movie_id]

# Initializing counter
total_keys = 0

# To Count and print keys for each endpoint
print(f"\nKey counts for movie ID {movie_id}:")
for endpoint in sorted(movie_data.keys()):
    try:
        keys = movie_data[endpoint].keys()
        num_keys = len(keys)
        total_keys += num_keys
        print(f"{endpoint}: {num_keys} keys")
    except AttributeError:
        print(f"{endpoint}: No nested keys")

print(f"\nTotal number of keys across all endpoints: {total_keys}")
# Out:
# Key counts for movie ID 98:
# credits: 2 keys
# details: 8 keys
# recommendations: 1 keys
# watch_providers: 1 keys
#
# Total number of keys across all endpoints: 12

# %%
movie = data_1[0]
movie_id = list(movie.keys())[0]
movie_data = movie[movie_id]


details = movie_data.get('details', {})
title = details.get('title', 'N/A')
runtime = details.get('runtime', 'N/A')
release_date = details.get('release_date', 'N/A')
genres = details.get('genres', 'N/A')
overview = details.get('overview', 'N/A')



# Printing the extracted details
print(f"Title: {title}")
print(f"Runtime: {runtime} minutes")
print(f"Release Date: {release_date}")
print(f"Genres: {genres}")
print(f"Overview: {overview}")
# Out:
# Title: Gladiator
# Runtime: 155 minutes
# Release Date: 2000-05-04
# Genres: [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 12, 'name': 'Adventure'}]
# Overview: In the year 180, the death of Emperor Marcus Aurelius throws the Roman Empire into chaos. Maximus is one of the Roman army's most capable and trusted generals, as well as a key advisor to the emperor. As Marcus' devious son Commodus ascends to the throne, Maximus is sentenced to execution. He escapes but is captured by slave traders. Renamed "Spaniard" and forced to become a gladiator, Maximus must battle to the death against other men for the amusement of paying audiences.

# %%
movie = data_1[0]
movie_id = list(movie.keys())[0]
movie_data = movie[movie_id]

# Extracting details
details = movie_data.get('details', {})
title = details.get('title', 'N/A')
runtime = details.get('runtime', 'N/A')
release_date = details.get('release_date', 'N/A')
genres = ', '.join([genre['name'] for genre in details.get('genres', [])])
overview = details.get('overview', 'N/A')
# movie_id = details.get('id', 'N/A')
original_language = details.get('original_language', 'N/A')
# popularity = details.get('popularity', 'N/A')

# Extracting credits
credits = movie_data.get('credits', {})
cast_list = credits.get('cast', [])
crew_list = credits.get('crew', [])

# Extracting recommendations
recommendations = movie_data.get('recommendations', {})
recommendation_results = recommendations.get('results', [])

# Extracting watch providers
watch_providers = movie_data.get('watch_providers', {})
watch_provider_results = watch_providers.get('results', {})

# Printing the extracted details
print(f"Title: {title}")
print(f"Runtime: {runtime} minutes")
print(f"Release Date: {release_date}")
print(f"Genres: {genres}")
print(f"Overview: {overview}")
# print(f"ID: {movie_id}")
print(f"Original Language: {original_language}")
# print(f"Popularity: {popularity}")

# Printing top 5 cast members
print("\nTop Cast:")
for cast_member in cast_list[:5]:
    name = cast_member.get('name', 'N/A')
    character = cast_member.get('character', 'N/A')
    print(f"{name} as {character}")

# Printing directors and producers
print("\nCrew:")
for crew_member in crew_list:
    if crew_member.get('job') in ['Director', 'Producer', 'Executive Producer']:
        name = crew_member.get('name', 'N/A')
        job = crew_member.get('job', 'N/A')
        print(f"{job}: {name}")

# Printing recommendations
print("\nRecommendations:")
for rec in recommendation_results:
    rec_title = rec.get('title', 'N/A')
    print(f"- {rec_title}")

# Printing watch providers without links
print("\nWatch Providers:")
for country, providers in watch_provider_results.items():
    print(f"Country: {country}")
    for provider_type in ['buy', 'rent', 'flatrate']:
        provider_list = providers.get(provider_type, [])
        if provider_list:
            names = [provider['provider_name'] for provider in provider_list]
            print(f"{provider_type.title()} Providers: {', '.join(names)}")
    print()
# Out:
# Title: Gladiator
# Runtime: 155 minutes
# Release Date: 2000-05-04
# Genres: Action, Drama, Adventure
# Overview: In the year 180, the death of Emperor Marcus Aurelius throws the Roman Empire into chaos. Maximus is one of the Roman army's most capable and trusted generals, as well as a key advisor to the emperor. As Marcus' devious son Commodus ascends to the throne, Maximus is sentenced to execution. He escapes but is captured by slave traders. Renamed "Spaniard" and forced to become a gladiator, Maximus must battle to the death against other men for the amusement of paying audiences.
# Original Language: en
#
# Top Cast:
# Russell Crowe as Maximus
# Joaquin Phoenix as Commodus
# Connie Nielsen as Lucilla
# Oliver Reed as Proximo
# Richard Harris as Marcus Aurelius
#
# Crew:
# Director: Ridley Scott
# Producer: David Franzoni
# Producer: Branko Lustig
# Producer: Douglas Wick
# Executive Producer: Laurie MacDonald
# Executive Producer: Walter F. Parkes
# Executive Producer: Ridley Scott
#
# Recommendations:
# - The Matrix
# - Saving Private Ryan
# - Braveheart
# - Harry Potter and the Deathly Hallows: Part 1
# - A Beautiful Mind
# - Sherlock Holmes
# - Live Free or Die Hard
# - Troy
# - American Beauty
# - The Green Mile
# - The Lion King
# - The Departed
# - Robin Hood
# - Mission: Impossible
# - 300
# - Titanic
# - The Prestige
# - Terminator 2: Judgment Day
# - The Terminator
# - The Intouchables
#
# Watch Providers:
# Country: US
# Buy Providers: Apple TV, Amazon Video, Google Play Movies, YouTube, Fandango At Home, Microsoft Store
# Rent Providers: Apple TV, Amazon Video, Google Play Movies, YouTube, Fandango At Home, Microsoft Store, Spectrum On Demand
# Flatrate Providers: fuboTV, Paramount Plus, Paramount Plus Apple TV Channel , Paramount+ Amazon Channel

# %%
#storing in a temp_df


import pandas as pd

movie = data_1[0]
movie_id = list(movie.keys())[0]
movie_data = movie[movie_id]

# Extracting details
details = movie_data.get('details', {})
title = details.get('title', 'N/A')
runtime = details.get('runtime', 'N/A')
release_date = details.get('release_date', 'N/A')
genres = ', '.join([genre['name'] for genre in details.get('genres', [])])
overview = details.get('overview', 'N/A')
movie_id = details.get('id', 'N/A')
original_language = details.get('original_language', 'N/A')
popularity = details.get('popularity', 'N/A')

# Extracting credits
credits = movie_data.get('credits', {})
cast_list = credits.get('cast', [])
crew_list = credits.get('crew', [])

# Extracting recommendations
recommendations = movie_data.get('recommendations', {})
recommendation_results = recommendations.get('results', [])

# Extracting watch providers
watch_providers = movie_data.get('watch_providers', {})
watch_provider_results = watch_providers.get('results', {})

# Creating a dictionary to store the data
data = {
    'Title': title,
    'Runtime': runtime,
    'Release Date': release_date,
    'Genres': genres,
    'Overview': overview,
    'Original Language': original_language,
    'Top Cast': ', '.join([f"{cast_member.get('name', 'N/A')} as {cast_member.get('character', 'N/A')}" for cast_member in cast_list[:5]]),
    'Directors and Producers': ', '.join([f"{crew_member.get('job', 'N/A')}: {crew_member.get('name', 'N/A')}" for crew_member in crew_list if crew_member.get('job') in ['Director', 'Producer', 'Executive Producer']]),
    'Recommendations': ', '.join([rec.get('title', 'N/A') for rec in recommendation_results]),
    'Watch Providers': ', '.join([f"{provider_type.title()} Providers: {', '.join([provider['provider_name'] for provider in providers.get(provider_type, [])])}" for country, providers in watch_provider_results.items() for provider_type in ['buy', 'rent', 'flatrate'] if providers.get(provider_type)])
}

# Creating a DataFrame
temp_1 = pd.DataFrame([data])

# %%
temp_1
# Out:
#        Title  Runtime Release Date                    Genres  \
# 0  Gladiator      155   2000-05-04  Action, Drama, Adventure
#
#                                             Overview Original Language  \
# 0  In the year 180, the death of Emperor Marcus A...                en
#
#                                             Top Cast  \
# 0  Russell Crowe as Maximus, Joaquin Phoenix as C...
#
#                              Directors and Producers  \
# 0  Director: Ridley Scott, Producer: David Franzo...
#
#                                      Recommendations  \
# 0  The Matrix, Saving Private Ryan, Braveheart, H...
#
#                                      Watch Providers
# 0  Buy Providers: Apple TV, Amazon Video, Google ...

# %% [markdown]
# ### Multiple Dataframes Method

# %%
# Assuming details dictionary is already filled as per your script
details_data = {
    'Title': title,
    'Runtime': runtime,
    'Release Date': release_date,
    'Genres': genres,
    'Overview': overview,
    'Original Language': original_language,
    'Movie ID': 98  # Hardcoded for this example
}

details_df = pd.DataFrame([details_data])

# %%
details_df
# Out:
#        Title  Runtime Release Date                    Genres  \
# 0  Gladiator      155   2000-05-04  Action, Drama, Adventure
#
#                                             Overview Original Language  \
# 0  In the year 180, the death of Emperor Marcus A...                en
#
#    Movie ID
# 0        98

# %%
# Assuming cast_list is a list of dictionaries as per your script
cast_data = [{'Movie ID': 98, 'Actor Name': member['name'], 'Role Name': member['character']} for member in cast_list]

cast_df = pd.DataFrame(cast_data)

# %%
cast_df
# Out:
#     Movie ID            Actor Name  \
# 0         98         Russell Crowe
# 1         98       Joaquin Phoenix
# 2         98        Connie Nielsen
# 3         98           Oliver Reed
# 4         98        Richard Harris
# 5         98          Derek Jacobi
# 6         98        Djimon Hounsou
# 7         98       David Schofield
# 8         98         John Shrapnel
# 9         98           Tomas Arana
# 10        98          Ralf Moeller
# 11        98   Spencer Treat Clark
# 12        98        David Hemmings
# 13        98        Tommy Flanagan
# 14        98      Sven-Ole Thorsen
# 15        98          Omid Djalili
# 16        98    Nicholas McGaughey
# 17        98            Chris Kell
# 18        98           Tony Curran
# 19        98            Mark Lewis
# 20        98            John Quinn
# 21        98           Alun Raglan
# 22        98          David Bailie
# 23        98           Chick Allan
# 24        98     David J. Nicholls
# 25        98      Al Hunter Ashton
# 26        98            Billy Dowd
# 27        98        Giannina Facio
# 28        98           Ray Calleja
# 29        98     Giorgio Cantarini
# 30        98         Malcolm Ellul
# 31        98           Ray Mangion
# 32        98    João Costa Menezes
# 33        98         Mike Mitchell
# 34        98          Antone Pagán
# 35        98  Norman Campbell Rees
# 36        98            Neil Roche
# 37        98            Paul Sacks
# 38        98        Steve Saunders
# 39        98            Brian Smyj
# 40        98        Richard Stride
# 41        98        Tony Tomlinson
# 42        98         Paul Woodadge
# 43        98          Michael Yale
#
#                                          Role Name
# 0                                          Maximus
# 1                                         Commodus
# 2                                          Lucilla
# 3                                          Proximo
# 4                                  Marcus Aurelius
# 5                                         Gracchus
# 6                                             Juba
# 7                                            Falco
# 8                                            Gaius
# 9                                          Quintus
# 10                                           Hagen
# 11                                          Lucius
# 12                                         Cassius
# 13                                          Cicero
# 14                                           Tiger
# 15                                    Slave Trader
# 16                              Praetorian Officer
# 17                                          Scribe
# 18                                     Assassin #1
# 19                                     Assassin #2
# 20                                        Valerius
# 21                             Praetorian Guard #1
# 22                                        Engineer
# 23                                   German Leader
# 24                                       Giant Man
# 25                                 Rome Trainer #1
# 26                                        Narrator
# 27                                   Maximus' Wife
# 28                               Lucius' Attendant
# 29                                    Maximus' Son
# 30                          Centurion (uncredited)
# 31                          Centurion (uncredited)
# 32                      Roman Soldier (uncredited)
# 33                            Fighter (uncredited)
# 34                            Fighter (uncredited)
# 35                Sedan Chair Carrier (uncredited)
# 36                      Roman Soldier (uncredited)
# 37  Catapult Commander Shouts "Loose" (uncredited)
# 38                   German Barbarian (uncredited)
# 39                 Coliseum Gladiator (uncredited)
# 40                          Swordsman (uncredited)
# 41                                Man (uncredited)
# 42                Germanian Barbarian (uncredited)
# 43                       Rome Citizen (uncredited)

# %%
crew_data = []
for crew_member in crew_list:
    if crew_member['job'] in ['Director', 'Producer', 'Executive Producer']:
        crew_data.append({
            'Movie ID': 98,
            'Name': crew_member['name'],
            'Job': crew_member['job']
        })

crew_df = pd.DataFrame(crew_data)

# %%
crew_df
# Out:
#    Movie ID              Name                 Job
# 0        98      Ridley Scott            Director
# 1        98    David Franzoni            Producer
# 2        98     Branko Lustig            Producer
# 3        98      Douglas Wick            Producer
# 4        98  Laurie MacDonald  Executive Producer
# 5        98  Walter F. Parkes  Executive Producer
# 6        98      Ridley Scott  Executive Producer

# %% [markdown]
# ## In Above Cells, Creating Multiple Dataframes for each endpoint and handling the complex realtions them primary keys

# %%
# # Extracting movie details
# movie_id = list(data_1[0].keys())[0]
# movie_data = data_1[0][movie_id]

# details = movie_data.get('details', {})
# movie_dict = {
#     'Title': details.get('title', 'N/A'),
#     'Runtime': details.get('runtime', 'N/A'),
#     'Release Date': details.get('release_date', 'N/A'),
#     'Genres': ', '.join([genre['name'] for genre in details.get('genres', [])]),
#     'Overview': details.get('overview', 'N/A')
# }

# # # Creating DataFrame
# # df = pd.DataFrame([movie_dict])  # Convert dictionary to DataFrame
# # print(df)

# %%
# Remove .DS_Store file if it exists
ds_store_path = os.path.join(root_data_dir, '.DS_Store')
if os.path.exists(ds_store_path):
    os.remove(ds_store_path)
    print('.DS_Store file removed')
else:
    print('.DS_Store file not found')
# Out:
# .DS_Store file not found

# %% [markdown]
# ### All the movies data into movie dataframe

# %%
def data_pipeline(root_dir):
    all_movie_details = []
    for year_dir in os.listdir(root_dir):
        year_path = os.path.join(root_dir, year_dir)
        if os.path.isdir(year_path):
            for json_file in sorted(os.listdir(year_path)):
                file_path = os.path.join(year_path, json_file)
                try:
                    with open(file_path, 'r', encoding='utf-8') as f:
                        data = json.load(f)

                    for movie in data:
                        movie_id = list(movie.keys())[0]
                        movie_data = movie[movie_id]
                        details = movie_data.get('details', {})

                        movie_details = {
                            'movie_id': movie_id,
                            'year': year_dir, # Add year
                            'Title': details.get('title', 'N/A'),
                            'Runtime': details.get('runtime', 'N/A'),
                            'Release Date': details.get('release_date', 'N/A'),
                            'Genres': ', '.join([genre['name'] for genre in details.get('genres', [])]),
                            'Overview': details.get('overview', 'N/A')
                        }
                        all_movie_details.append(movie_details)
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON in {file_path}: {e}")
                except Exception as e: #catch all other exceptions
                  print(f"An unexpected error occurred: {e}")
    return pd.DataFrame(all_movie_details)

# %%
# Example usage
movie_df = data_pipeline(root_data_dir)

# %%
movie_df.tail(5)
# Out:
#        movie_id  year                                             Title  \
# 234847   533005  2004                                Whispering Pines 3
# 234848   531637  2004                           Secrets of Pearl Harbor
# 234849   532486  2004                       Los hijos del último jardín
# 234850   530897  2004                       Comme un poisson dans l'eau
# 234851   531628  2004  Quest for Columbus: In Search of the Santa Maria
#
#        Runtime Release Date    Genres  \
# 234847       8   2004-01-01
# 234848      44   2004-12-10
# 234849       0   2004-01-01  Thriller
# 234850      18   2004-01-21
# 234851      44   2004-03-01
#
#                                                  Overview
# 234847  In her celebrated video art serial, Whispering...
# 234848  Dennis Haysbert dives 160 feet beneath the wav...
# 234849
# 234850  Daniel is in search of happiness, of human rel...
# 234851  Quest for Columbus: In Search of the Santa Mar...

# %%
movie_df.columns
# Out:
# Index(['movie_id', 'year', 'Title', 'Runtime', 'Release Date', 'Genres',
#        'Overview'],
#       dtype='object')

# %%
movie_df.shape
# Out:
# (234852, 7)

# %% [markdown]
# ## Storing Data in different formats, future purpose

# %%
# movie_df.to_csv('movie_data.csv', index=False)

# movie_df.to_pickle('movie_data.pkl')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[70], line 5
#       1 movie_df.to_csv('movie_data.csv', index=False)
#       3 movie_df.to_pickle('movie_data.pkl')
# ----> 5 movie_df.to_parquet('movie_data.parquet')
#
# File ~/Desktop/GitHub/CineAI/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/Desktop/GitHub/CineAI/venv/lib/python3.9/site-packages/pandas/core/frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)
#    3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File ~/Desktop/GitHub/CineAI/venv/lib/python3.9/site-packages/pandas/io/parquet.py:476, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     474 if isinstance(partition_cols, str):
#     475     partition_cols = [partition_cols]
# --> 476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     480 impl.write(
#     481     df,
#     482     path_or_buf,
#    (...)
#     488     **kwargs,
#     489 )
#
# File ~/Desktop/GitHub/CineAI/venv/lib/python3.9/site-packages/pandas/io/parquet.py:67, in get_engine(engine)
#      64         except ImportError as err:
#      65             error_msgs += "\n - " + str(err)
# ---> 67     raise ImportError(
#      68         "Unable to find a usable engine; "
#      69         "tried using: 'pyarrow', 'fastparquet'.\n"
#      70         "A suitable version of "
#      71         "pyarrow or fastparquet is required for parquet "
#      72         "support.\n"
#      73         "Trying to import the above resulted in these errors:"
#      74         f"{error_msgs}"
#      75     )
#      77 if engine == "pyarrow":
#      78     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %%
# !pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-18.1.0-cp39-cp39-macosx_12_0_x86_64.whl.metadata (3.3 kB)
# Downloading pyarrow-18.1.0-cp39-cp39-macosx_12_0_x86_64.whl (30.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.9/30.9 MB 34.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyarrow
# Successfully installed pyarrow-18.1.0

# %%
# movie_df.to_parquet('movie_data.parquet')

# Data is stored in different formats

# %%
# df copy
movie_df_copy = movie_df.copy()

# %%
#copy of movie_df

movie_df_copy.shape
# Out:
# (234852, 7)

# %% [markdown]
# # Performing EDA Aanalysis

# %%
# Check for missing values in each column
movie_df_copy.isnull().sum()
# Out:
# movie_id        0
# year            0
# Title           0
# Runtime         0
# Release Date    0
# Genres          0
# Overview        0
# dtype: int64

# %%
# Drop rows with missing values
movie_df_copy = movie_df.dropna()

# %%
movie_df_copy.columns
# Out:
# Index(['movie_id', 'year', 'Title', 'Runtime', 'Release Date', 'Genres',
#        'Overview'],
#       dtype='object')

# %%
# Basic statistics
print("Dataset Shape:", movie_df_copy.shape)
print("\nBasic Statistics:")
print(movie_df_copy.describe())
# Out:
# Dataset Shape: (234852, 7)
#
# Basic Statistics:
#        movie_id    year   Title  Runtime Release Date       Genres Overview
# count    234852  234852  234852   234852       234852       234852   234852
# unique   230587      24  207028      462         8768         7645   206276
# top     1193094    2013    Home        0   2003-01-01  Documentary
# freq          3   10000      46    30538         2288        34654    23240

# %%
# Data quality checks
quality_check = {
    'nulls': movie_df_copy.isnull().sum(),
    'zeros': (movie_df_copy[['movie_id', 'year', 'Runtime']] == 0).sum(),
    'empty_strings': (movie_df_copy[['Title', 'Genres', 'Overview']] == '').sum(),
    'duplicate_rows': movie_df_copy.duplicated().sum(),
    'invalid_dates': pd.to_datetime(movie_df_copy['Release Date'], errors='coerce').isnull().sum()
}

# %%
print("Data Quality Report:")
for check, result in quality_check.items():
    print(f"\n{check.upper()}:")
    print(result)
# Out:
# Data Quality Report:
#
# NULLS:
# movie_id        0
# year            0
# Title           0
# Runtime         0
# Release Date    0
# Genres          0
# Overview        0
# dtype: int64
#
# ZEROS:
# movie_id        0
# year            0
# Runtime     30538
# dtype: int64
#
# EMPTY_STRINGS:
# Title           0
# Genres      31251
# Overview    23240
# dtype: int64
#
# DUPLICATE_ROWS:
# 4265
#
# INVALID_DATES:
# 7

# %%
# !pip install matplotlib
# !pip install seaborn

# %%
# Create a comprehensive data quality report with visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Calculate quality metrics
quality_check = {
    'nulls': movie_df.isnull().sum(),
    'zeros': (movie_df[['movie_id', 'year', 'Runtime']] == 0).sum(),
    'empty_strings': (movie_df[['Title', 'Genres', 'Overview']] == '').sum(),
    'duplicate_rows': movie_df.duplicated().sum(),
    'invalid_dates': pd.to_datetime(movie_df['Release Date'], errors='coerce').isnull().sum()
}

# 2. Create visualizations
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))

# Zero values in numeric columns
quality_check['zeros'].plot(kind='bar', ax=ax2)
ax2.set_title('Zero Values in Numeric Columns')
ax2.tick_params(axis='x', rotation=45)

# Empty strings in text columns
quality_check['empty_strings'].plot(kind='bar', ax=ax3)
ax3.set_title('Empty Strings in Text Columns')
ax3.tick_params(axis='x', rotation=45)

# Missing dates visualization
dates_valid = pd.to_datetime(movie_df['Release Date'], errors='coerce')
dates_valid.value_counts().resample('Y').count().plot(ax=ax4)
ax4.set_title('Valid Dates Distribution by Year')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qg/2qk8qwz14y14_d03ypk9m02h0000gq/T/ipykernel_49170/3741263664.py:29: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates_valid.value_counts().resample('Y').count().plot(ax=ax4)
# Data Quality Report Summary:
# Total rows: 234852
# Duplicate rows: 4265
# Invalid dates: 7
#
# Percentage of missing values by column:
# movie_id        0.0
# year            0.0
# Title           0.0
# Runtime         0.0
# Release Date    0.0
# Genres          0.0
# Overview        0.0
# dtype: float64

# %%
# Print detailed report
print("\nData Quality Report Summary:")
print(f"Total rows: {len(movie_df)}")
print(f"Duplicate rows: {quality_check['duplicate_rows']}")
print(f"Invalid dates: {quality_check['invalid_dates']}")
print("\nPercentage of missing values by column:")
print((movie_df.isnull().sum() / len(movie_df) * 100).round(2))
# Out:
# Data Quality Report Summary:
# Total rows: 234852
# Duplicate rows: 4265
# Invalid dates: 7
#
# Percentage of missing values by column:
# movie_id        0.0
# year            0.0
# Title           0.0
# Runtime         0.0
# Release Date    0.0
# Genres          0.0
# Overview        0.0
# dtype: float64

# %%
# Extract duplicate rows (including all occurrences)
duplicate_rows = movie_df_copy[movie_df_copy.duplicated(keep=False)]

# Display the duplicate rows
print(f"Total duplicate rows: {len(duplicate_rows)}")
duplicate_rows.sort_values(by=['Title', 'year'])
# Out:
# Total duplicate rows: 8492
#        movie_id  year                            Title Runtime Release Date  \
# 152258  1320023  2021                     #50ForDaCity      72   2021-12-07
# 155753  1320023  2021                     #50ForDaCity      72   2021-12-07
# 35748   1092606  2023                            #MUTE       0   2023-02-27
# 38405   1092606  2023                            #MUTE       0   2023-02-27
# 21344   1028550  2022                            #Xmas      84   2022-11-25
# ...         ...   ...                              ...     ...          ...
# 39420   1330792  2023  鴛鴦歌合戦（おしどりうたがっせん）／GRAND MIRAGE!       0   2023-07-07
# 152021   888032  2021                       보는 것을 사랑한다       0   2021-10-28
# 155415   888032  2021                       보는 것을 사랑한다       0   2021-10-28
# 32235   1129931  2023                      어린 며느리 길들이기       0   2023-04-27
# 32250   1129931  2023                      어린 며느리 길들이기       0   2023-04-27
#
#                                   Genres  \
# 152258                       Documentary
# 155753                       Documentary
# 35748                           Thriller
# 38405                           Thriller
# 21344   TV Movie, Comedy, Drama, Romance
# ...                                  ...
# 39420
# 152021                       Documentary
# 155415                       Documentary
# 32235                              Drama
# 32250                              Drama
#
#                                                  Overview
# 152258  Zach Randolph Documentary. This documentary fi...
# 155753  Zach Randolph Documentary. This documentary fi...
# 35748   A lone divorcee sets the race against time to ...
# 38405   A lone divorcee sets the race against time to ...
# 21344   When Jen gets the chance to enter a brand’s de...
# ...                                                   ...
# 39420
# 152021
# 155415
# 32235
# 32250
#
# [8492 rows x 7 columns]

# %% [markdown]
# ### Unstructerd dataframe data with Data Wrangler extension powered by Microsoft

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# to load in Data Wrangler
# # Loaded variable 'df' from URI: /Users/HVMS/Desktop/GitHub/CineAI/src/preprocessing/Data_Storage/Raw Data/movie_data.csv
# import pandas as pd
# df = pd.read_csv(r'/Users/HVMS/Desktop/GitHub/CineAI/src/preprocessing/Data_Storage/Raw Data/movie_data.csv', index_col=None, header=0, engine='python')
